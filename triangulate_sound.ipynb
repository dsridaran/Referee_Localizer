# %% [markdown]
# <a href="https://colab.research.google.com/github/dsridaran/All_Ears/blob/main/triangulate_sound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preliminaries

# %%
# Define working directory
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/FIFA/Cloned Repository/All_Ears/src

# Imports
from data_preprocessing import load_unique_ref_positions
from models import localize_whistle
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/.shortcut-targets-by-id/1oF2xDqmAbEcHI3KqIc48ey_Q88_tnlPx/FIFA/Cloned Repository/All_Ears/src

# %% [markdown]
# # Load Known Referee Positions

# %%
actual_positions = load_unique_ref_positions(
    whistles_path = "../data/meta/whistles_CRO_BRA_Tagged.csv",
    ref_track_path = "../data/meta/refs_track_BRA_CRO.parquet"
)

# %% [markdown]
# # Perform Localization

# %%
illustrative_example = localize_whistle(
    # Define whistle
    file_path = "../data/snipped", whistle = 89, plot = True,
    # Physical dimensions
    field_length = 120, field_width = 60, speed_of_sound = 343, grid_size = 1,
    # Frequency limits
    lowcut = 3000, highcut = 5000,
    # Known referee positions
    unique_positions = actual_positions,
    # Microphone location pertubations
    perturb_threshold = 0, mic_index = None
)
# Out:
# Actual source location: (-18.53, 4.8)
# Estimated source location (single): (-9.0, -8.0)
# Estimated source location (mean, all): (-9.522058823529411, -1.741421568627451)
# Estimated source location (mean, non-boundary): (-11.744282744282744, 1.476091476091476)
# Estimated source location (median, all): (-14.0, 1.0)
# Estimated source location (median, non_boundary): (-16.0, 3.0)
# ((-18.53, 4.8),
#  (-9.0, -8.0),
#  (-9.522058823529411, -1.741421568627451),
#  (-11.744282744282744, 1.476091476091476),
#  (-14.0, 1.0),
#  (-16.0, 3.0))
